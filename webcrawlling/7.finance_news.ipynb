# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def get_naver_finance_news(date: str = None):
    """
    date: 'YYYY-MM-DD' 형식, None이면 오늘 주요뉴스
    """
    url = 'https://finance.naver.com/news/mainnews.naver'
    if date:
        url += f'?date={date}'
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                      'AppleWebKit/537.36 (KHTML, like Gecko) '
                      'Chrome/120.0.0.0 Safari/537.36'
    }
    
    response = requests.get(url, headers=headers)
    response.encoding = 'euc-kr'  # 네이버 인코딩
    soup = BeautifulSoup(response.text, 'lxml')
    
    news_list = []
    items = soup.select('div.mainNewsList._replaceNewsLink ul li')
    
    for item in items:
        # 제목
        title_tag = item.select_one('dd.articleSubject a')
        title = title_tag.get_text(strip=True) if title_tag else None
        link  = 'https://finance.naver.com' + title_tag['href'] if title_tag else None
        
        # 써머리
        summary_tag = item.select_one('dd.articleSummary')
        summary = summary_tag.get_text(strip=True) if summary_tag else None
        
        
        if title:
            news_list.append({
                'title'  : title,
                'summary': summary
                })
    
    df = pd.DataFrame(news_list)
    return df


# 사용 예시
df = get_naver_finance_news(date='2026-02-20')
print(df.shape)
print(df.head())
# Out:
# (20, 2)
#                                                title  \
# 0  2월 10일 옵션 만기의 폭풍 속에서도 기관의 강력한 드라이브가 포착... <진짜주...
# 1  2차전지·남북 경협·반도체 등 전문가 심층 분석, MSCI 선진 지수 편입 등 시장...
# 2               "열흘 안에 결판" 트럼프 한마디에…주가 들썩이는 종목 [종목+]
# 3                          심상찮은 전운에…한국도 미국도 대장주 '화력'
# 4             SK하이닉스, 장중 '95만닉스' 터치… '100만닉스' 시대 가시권
#
#                                              summary
# 0  2월 10일 옵션 만기의 폭풍 속에서도 기관의 강력한 드라이브가 포착됐다. 삼성전자...
# 1  한국경제TV의 새로운 투자 추리 토크쇼 가 시청자들의 뜨거운 관심 속에 문을 열었다...
# 2  미국과 이란의 지정학적 긴장감이 고조되면서 방산주가 강세를 나타냈다. 20일 한국거...
# 3  미국의 대(對)이란 공격이 임박했다는 징후가 포착되면서 글로벌 방산주가 화력을 뿜었...
# 4  SK하이닉스, 삼성전자 종가는? SK하이닉스가 20일 장중 한때 95만원 선을 돌파...

# %%
df
# Out:
#                                                 title  \
# 0   2월 10일 옵션 만기의 폭풍 속에서도 기관의 강력한 드라이브가 포착... <진짜주...
# 1   2차전지·남북 경협·반도체 등 전문가 심층 분석, MSCI 선진 지수 편입 등 시장...
# 2                "열흘 안에 결판" 트럼프 한마디에…주가 들썩이는 종목 [종목+]
# 3                           심상찮은 전운에…한국도 미국도 대장주 '화력'
# 4              SK하이닉스, 장중 '95만닉스' 터치… '100만닉스' 시대 가시권
# 5                    코스피, 5800까지 뚫자…'공포지수'는 올랐다, 의미는?
# 6              정부, 반려동물 전담 부처 내달 확정… ‘동물복지원’ 설립 논의 가속
# 7   5800 뚫은 코스피, 진짜 ‘육천피’ 가나…美 한파에도 SK하이닉스 ‘95만닉스’...
# 8                  美대법원 관세 판결 촉각…"트럼프 11월 중간선거 '갈림길'"
# 9                     "불금에 어울리는 음악 만들어줘"…AI가 작사·작곡 뚝딱
# 10            "밀가루도 5.8조 원어치 6년간 담합"…설탕 이어 역대급 과징금 예고
# 11            봄 이사철 코앞인데 사라지는 전세…1천 가구 대단지 '전세 0건' 속출
# 12                  'IPO 삼수' 케이뱅크, 일반청약 돌입...증시 입성 눈앞
# 13                   삼성전자 사장단, 작년 성과급 주식보상 수령…전영현 17억
# 14                     "美 기술주 대안"…글로벌 자금 유럽 증시로 '대이동'
# 15                        ‘폭락’ 이후 銀 ETF 사들이는 개미들…전망은?
# 16               임시주총 앞둔 인크레더블버즈, 과거 자본거래 구조 살펴보니....
# 17   휴머노이드 상용화 경쟁에 성장 가속…액티브 전략으로 1년 수익률 125%[ETF 줌인]
# 18                           연금계좌서도 공격 투자…채권혼합 ETF 뜬다
# 19                   블랙록이 4대주주로…SK하이닉스 신고가 경신 [마켓시그널]
#
#                                               summary
# 0   2월 10일 옵션 만기의 폭풍 속에서도 기관의 강력한 드라이브가 포착됐다. 삼성전자...
# 1   한국경제TV의 새로운 투자 추리 토크쇼 가 시청자들의 뜨거운 관심 속에 문을 열었다...
# 2   미국과 이란의 지정학적 긴장감이 고조되면서 방산주가 강세를 나타냈다. 20일 한국거...
# 3   미국의 대(對)이란 공격이 임박했다는 징후가 포착되면서 글로벌 방산주가 화력을 뿜었...
# 4   SK하이닉스, 삼성전자 종가는? SK하이닉스가 20일 장중 한때 95만원 선을 돌파...
# 5   코스피지수가 연일 상승세를 이어가며 5600선을 넘어선지 하루 만에 5800선까지 ...
# 6   정부가 반려동물 정책을 전담할 부처를 내달 중 최종 확정한다. 국무조정실은 20일 ...
# 7   전날 5600 돌파 이어 5700·5800 순차 정복 기관, 1.6조 순매수…외인·...
# 8   주현수 한국금융연구원 교수는 20일 한국경제TV에 출연해 "미국 연방 대법원이 현 ...
# 9   AI가 진짜 같은 이미지와 영상을 만들어내는 데 이어 이제는 음악까지 작사, 작곡을...
# 10  얼마 전 설탕에 이어 이번엔 밀가루입니다. 빵값이 가파르게 올라 이유가 궁금했었는데...
# 11  세를 준 집도 팔 수 있도록 다주택자들에게 퇴로를 열어주면서 매매 물건은 다행히 크...
# 12  올해 상반기 기업공개(IPO) 최대어로 꼽히는 케이뱅크가 오는 23일까지 공모주 청...
# 13  노태문 11억·박학규 9억대 삼성전자 반도체 사업을 이끄는 전영현 삼성전자 디바이스...
# 14  미국 기술주에 대한 부담이 커지면서 글로벌 자금이 유럽 증시로 빠르게 이동하고 있다...
# 15  국제 은 가격이 지난 1월 말 급락 이후 은 관련 상장지수펀드(ETF)에 대한 개인...
# 16  오는 23일 개최 예정인 인크레더블버즈 임시주주총회를 앞두고, 과거 최대주주 변경 ...
# 17  글로벌 빅테크 기업들이 휴머노이드 로봇 상용화 경쟁에 속도를 내자 관련 산업에 대한...
# 18  주식과 채권을 일정 비율로 담는 채권혼합형 상장지수펀드(ETF) 시장이 순자산 10...
# 19  세계 최대 자산운용사 블랙록이 SK하이닉스(000660)의 지분 5%를 보유하며 4...
