# %% [markdown]
# # 안녕하세요

# %%
#안녕하세요
print ("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
안녕하세요 = 3030
print(안녕하세요)
# Out:
# 3030

# %%
### print(안녕하세요)

# %%
# #'''rkskeksksksk
# fnfnfnfnfnnfn

# %%
'''nrjrkrkrkrkrkrkr \n rnrnrnrnrnrnrn'''
# Out:
# 'nrjrkrkrkrkrkrkr \n rnrnrnrnrnrnrn'

# %%
3*4
4*5
# Out:
# 20

# %%
# 가나다
# 나다라
# 다라마

# %%
'''안녕하세요
반갑습니다.'''
# Out:
# '안녕하세요\n반갑습니다.'

# %%
print ("""안녕하세요 
       반갑습니다""")
# Out:
# 안녕하세요
#        반갑습니다

# %%
"""안녕하세요
반갑습니다"""
# Out:
# '안녕하세요\n반갑습니다'

# %%
'''안녕하세요
반갑습니다'''
# Out:
# '안녕하세요\n반갑습니다'

# %%
print(name)
# Out:
# 고휘주

# %%
def calculate_sum(a, b):
    result = a+b # 들여쓰기된 코드 블록
    return result # 같은 레벨의 들여쓰기

result = calculate_sum(3,4)

if result > 0:
    print(result)
    print("양수입니다")   #if문내부의 들여쓰기된 코드
# Out:
# 7
# 양수입니다

# %%
result = 2

# %%
print(result)
# Out:
# 7

# %% [markdown]
# 안녕하세요
# **굵게**

# %% [markdown]
# <h1> 안녕 </h1>

# %% [markdown]
# <h1>안녕하세요</h1>
# <h2>안녕</h2>
# <h3>안</h3>
# #녕안

# %% [markdown]
# #안녕안녕안녕

# %%
print (result)
# Out:
# 7

# %% [markdown]
# * 안녕
#   - 녕안

# %% [markdown]
# * 안녕
#   - 녕안

# %% [markdown]
# ## 리스트
#     순서가 없는 리스트 만들기
#     * 하나
#     * 둘
#     * 셋

# %% [markdown]
# 순서가 있는 리스트 만들기
# 1. 하나
# 2. 둘
# 3. 셋

# %% [markdown]
# ##### 탭을 이용한 순서가 없는 서브리스트
#     * 첫번째
#      - 서브리스트 1
#         - 아이템 1
#         - 아이템 2
#
#     - 서브리스트 2
#         - 아이템 3
#
#     * 두번째
#      - 서브리스트 3

# %% [markdown]
# ## 글자 효과
#
# **굵게** <U>밑줄<w> *기울이기*

# %% [markdown]
# ## 표
# <div align="center">
# **개구리 점프**
#     </div>
#
#
# | 번호 | 내용 | 주의사항 |
# |-----|-----|-----|
# | 1 | 개구리 |
# | 2 | 도마뱀

# %% [markdown]
# [Google](<https://www.google.com>)
#
# ![Jupyter Logo](<https://jupyter.org/assets/homepage/main-logo.svg>)

# %% [markdown]
# ![image.png](attachment:780ab280-57d6-4790-93da-87b301ded63f.png)
