# %% [markdown]
# [Jupyter](https://jupyter.org/)

# %% [markdown]
# ![Arsenal Logo](https://i.namu.wiki/i/Jid2IalqNOCAgnfFjIgsHqYlMs7pOxZ5BaYhac8B9-yfyNpx3rMdzgKmVI4IuWvI2tuV-igjoTw8xtgr3nxRXELdjNnKX3BTmyLfoXv_aB9IyZ-6UjwIVpVGbODPsnepgQtOpn8KfV1RApS7PvdH_g.svg)

# %% [markdown]
# | | | |
# | --- | --- | --- |
# | 가위 | 바위 | 보 |

# %% [markdown]
# **굵게**

# %% [markdown]
# - 안녕
#     - 녕안

# %%
print ( "A", "B", "C" )
# Out:
# A B C

# %%
print ( "A", "B", "C", sep= "-" )
print ( "2025", "12", "21", sep= "/" )
# Out:
# A-B-C
# 2025/12/21

# %%
print ( "로딩 중", end="..." )
print ( "완료!" )
# Out:
# 로딩 중...완료!

# %%
print ( "로딩 중", end = "..." )
print ( "완료!" )
# Out:
# 로딩 중...완료!

# %%
print ( "로딩 중", end = "... \n" )
print ( "완료!" )
# Out:
# 로딩 중...
# 완료!

# %%
for i in range (3):
    print (".", end="")

import time
for i in range (5):
    print (f"진행: {i+1}", end="\r", flush=True)
    time.sleep(1)
# Out:
# 진행: 5: 1

# %%
print ( "Hello World" )
# Out:
# Hello World

# %%
print ( "Mary's cosmetics" )
# Out:
# Mary's cosmetics

# %%
print ( '"도둑이야"' )
# Out:
# "도둑이야"

# %%
전기매출 = input ("전기매출은 ")
당기매출 = input ("당기매출은 ")
매출성장율 = (당기매출/전기매출 - 1) * 100
print ( 매출성장율 )
# Out:
# 전기매출은  1000
# 당기매출은  2500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 전기매출 = input ("전기매출은 ")
#       2 당기매출 = input ("당기매출은 ")
# ----> 3 매출성장율 = (당기매출/전기매출 - 1) * 100
#       4 print ( 매출성장율 )
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
전기매출 = int ( input ( "전기매출은 " ) )
당기매출 = int ( input ( "당기매출은 " ) )
매출성장율 = (당기매출 / 전기매출 - 1) * 100
print ( 매출성장율+"%" )
# Out:
# 전기매출은  1000
# 당기매출은  2500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 당기매출 = int ( input ( "당기매출은 " ) )
#       3 매출성장율 = (당기매출 / 전기매출 - 1) * 100
# ----> 4 print ( 매출성장율+"%" )
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
전기매출 = int ( input ( "전기매출은 " ) )
당기매출 = int ( input ( "당기매출은 " ) )
매출성장율 = (당기매출 / 전기매출 - 1) * 100
print ( str(매출성장율)+"%" )
# Out:
# 전기매출은  1000
# 당기매출은  2500
# 150.0%

# %%
aa = 'abcdefghijklmn'
print ( aa.split('f') )
# Out:
# ['abcde', 'ghijklmn']

# %%
print ( aa.split('f')[2] )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print ( aa.split('f')[2] )
#
# IndexError: list index out of range

# %%
aa.split(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 aa.split(3)
#
# TypeError: must be str or None, not int

# %%
text = "apple banana orange mellon"
result = text.split(" ")
print (result)
# Out:
# ['apple', 'banana', 'orange', 'mellon']

# %%
print ( text )
# Out:
# apple banana orange mellon

# %%
print ( text.split() )
# Out:
# ['apple', 'banana', 'orange', 'mellon']

# %%
person = {"이름": "Alice", "나이": 25, "도시": "서울"}

# 값 추가
person["직업"] = "개발자"

# 값 수정
person["나이"] = 26

# 키 삭제
del person["도시"]

# %%
print(person.keys())     # dict_keys(['이름', '나이', '직업'])
print(person.values())   # dict_values(['Alice', 26, '개발자'])
print(person.items())    # dict_items([('이름', 'Alice'), ('나이', 26), ('직업', '개발자')])
print(person.pop("나이"))# 26
# Out:
# dict_keys(['이름', '나이', '직업'])
# dict_values(['Alice', 26, '개발자'])
# dict_items([('이름', 'Alice'), ('나이', 26), ('직업', '개발자')])
# 26

# %%
person.update({"나나이이":26})

# %%
print(person)
# Out:
# {'이름': 'Alice', '직업': '개발자', '나나이이': 26}
