# %% [markdown]
# # inmemorycache 테스트

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

set_llm_cache(InMemoryCache())
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]

# %%
# 첫 번째 호출 - API 실제 호출, set_llm_cache사용
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 가장 인기 있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤한 고추장 소스에 볶아낸 떡볶이는 많은 사람들에게 사랑받는 대표적인 길거리 음식입니다.
# 2. **오뎅**: 따뜻한 국물과 함께 제공되는 오뎅은 간편하게 즐길 수 있는 겨울철 간식입니다.
# 3. **순대**: 돼지 내장과 당면 등으로 만든 순대는 매운 소스와 함께 먹으면 더욱 맛있습니다.
# 4. **핫도그**: 다양한 토핑을 얹은 핫도그는 아이들과 어른 모두에게 인기 있는 간식입니다.
# 5. **붕어빵**: 고소한 붕어빵은 팥, 크림 등의 소를 채워 넣어 따뜻하게 즐길 수 있습니다.
# 6. **김밥**: 간편하게 식사 대용으로 즐길 수 있는 김밥은 여러 가지 속재료로 다양하게 맛볼 수 있습니다.
#
# 광장시장은 항상 많은 사람들이 방문하는 곳이므로, 다양한 길거리 음식을 즐기기에 좋은 장소입니다.

# %%
# 첫 번째 호출 - API 실제 호출, cache에 결과 저장
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 가장 인기 있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤한 고추장 소스에 볶아낸 떡볶이는 많은 사람들에게 사랑받는 대표적인 길거리 음식입니다.
# 2. **오뎅**: 따뜻한 국물과 함께 제공되는 오뎅은 간편하게 즐길 수 있는 겨울철 간식입니다.
# 3. **순대**: 돼지 내장과 당면 등으로 만든 순대는 매운 소스와 함께 먹으면 더욱 맛있습니다.
# 4. **핫도그**: 다양한 토핑을 얹은 핫도그는 아이들과 어른 모두에게 인기 있는 간식입니다.
# 5. **붕어빵**: 고소한 붕어빵은 팥, 크림 등의 소를 채워 넣어 따뜻하게 즐길 수 있습니다.
# 6. **김밥**: 간편하게 식사 대용으로 즐길 수 있는 김밥은 여러 가지 속재료로 다양하게 맛볼 수 있습니다.
#
# 광장시장은 항상 많은 사람들이 방문하는 곳이므로, 다양한 길거리 음식을 즐기기에 좋은 장소입니다.

# %% [markdown]
# # SQLiteCache(database_path=".langchain.db")

# %%
from langchain_community.cache import SQLiteCache
set_llm_cache(SQLiteCache(database_path=".langchain.db"))

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 인기 있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤한 소스에 쫄깃한 떡이 들어간 대표적인 한국 스트리트 푸드입니다.
# 2. **순대**: 순대는 한국식 소시지로, 보통 돼지 내장과 당면, 야채로 만들어집니다.
# 3. **오뎅(어묵)**: 맑은 국물에 끓인 어묵은 많은 사람들이 즐기는 겨울철 간식입니다.
# 4. **볶음밥**: 다양한 재료가 들어간 볶음밥도 빠질 수 없는 인기 메뉴입니다.
# 5. **핫도그**: 한국식 핫도그는 쫄깃한 밀가루 반죽에 소시지를 넣고 튀겨서 만들어지며, 여러 가지 소스와 토핑을 추가할 수 있습니다.
#
# 이 외에도 여러 다양한 음식들이 있으니, 직접 가셔서 여러 가지를 맛보시길 추천합니다!

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 인기 있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤한 소스에 쫄깃한 떡이 들어간 대표적인 한국 스트리트 푸드입니다.
# 2. **순대**: 순대는 한국식 소시지로, 보통 돼지 내장과 당면, 야채로 만들어집니다.
# 3. **오뎅(어묵)**: 맑은 국물에 끓인 어묵은 많은 사람들이 즐기는 겨울철 간식입니다.
# 4. **볶음밥**: 다양한 재료가 들어간 볶음밥도 빠질 수 없는 인기 메뉴입니다.
# 5. **핫도그**: 한국식 핫도그는 쫄깃한 밀가루 반죽에 소시지를 넣고 튀겨서 만들어지며, 여러 가지 소스와 토핑을 추가할 수 있습니다.
#
# 이 외에도 여러 다양한 음식들이 있으니, 직접 가셔서 여러 가지를 맛보시길 추천합니다!

# %%
message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 음식은?")]

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장은 다양한 전통 한국 음식을 즐길 수 있는 장소로 유명합니다. 그 중에서도 특히 추천하는 음식은 다음과 같습니다:
#
# 1. **오징어볶음**: 매콤한 양념에 볶아진 오징어와 채소가 어우러져 맛있습니다.
# 2. **떡볶이**: 쫄깃한 떡과 매콤한 소스가 조화를 이루며 많은 사람들이 선호하는 간식입니다.
# 3. **순대**: 고추장이나 간장 소스와 함께 먹는 순대는 고소하고 풍미가 가득합니다.
# 4. **호떡**: 달콤한 속이 가득 들어간 호떡은 겨울철 간식으로 인기가 많습니다.
# 5. **김밥**: 다양한 재료로 속을 채운 김밥은 간편하면서도 영양가가 높은 음식입니다.
#
# 광장시장에서 맛있는 음식을 즐기며 다양한 노점상을 탐방해보시는 것도 좋은 경험이 될 것입니다!

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장은 다양한 전통 한국 음식을 즐길 수 있는 장소로 유명합니다. 그 중에서도 특히 추천하는 음식은 다음과 같습니다:
#
# 1. **오징어볶음**: 매콤한 양념에 볶아진 오징어와 채소가 어우러져 맛있습니다.
# 2. **떡볶이**: 쫄깃한 떡과 매콤한 소스가 조화를 이루며 많은 사람들이 선호하는 간식입니다.
# 3. **순대**: 고추장이나 간장 소스와 함께 먹는 순대는 고소하고 풍미가 가득합니다.
# 4. **호떡**: 달콤한 속이 가득 들어간 호떡은 겨울철 간식으로 인기가 많습니다.
# 5. **김밥**: 다양한 재료로 속을 채운 김밥은 간편하면서도 영양가가 높은 음식입니다.
#
# 광장시장에서 맛있는 음식을 즐기며 다양한 노점상을 탐방해보시는 것도 좋은 경험이 될 것입니다!

# %% [markdown]
# # Redis Semantic Cache

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
REDIS_URL = os.environ['REDIS_URL']

# %%
from langchain_core.globals import set_llm_cache
from langchain_redis import RedisSemanticCache          # 변경
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.messages import HumanMessage

# %%
semantic_cache = RedisSemanticCache(
    redis_url=REDIS_URL,
    embeddings=OpenAIEmbeddings(model="text-embedding-3-small"),  # 파라미터명 변경
    distance_threshold=0.02  # 파라미터명 변경
)

set_llm_cache(semantic_cache)

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
response = llm.invoke([HumanMessage(content="코스피200 지수란 무엇인가요? 한 문장으로 답해주세요.")])
print(response.content)
# Out:
# 코스피 지수는 한국거래소에 상장된 주식들의 시가총액을 기준으로 계산된 한국 주식시장의 대표적인 주가지수입니다.

# %%
semantic_cache.clear()

# %%
response = llm.invoke([HumanMessage(content="코스피200 지수란 무엇인가요? 한 문장으로 답해주세요.")])
print(response.content)
# Out:
# 코스피200 지수는 한국거래소에서 상장된 200개의 대표적인 대형 주식으로 구성된 주가 지수로, 한국 주식 시장의 전반적인 동향을 나타냅니다.

# %%
semantic_cache.clear()

# %%
response_merton = llm.invoke([HumanMessage(content="부도율 추정과 관련해서 머튼모델에 대해서 설명해주세요.")])
print(response_merton.content)
# Out:
# 머튼 모델(Merton Model)은 기업의 신용 리스크와 부도율을 평가하기 위한 중요한 금융 이론 중 하나입니다. 이 모델은 1974년에 로버트 머튼(Robert Merton)에 의해 제안되었으며, 주어진 회사의 채무 불이행 위험을 주식 옵션의 가치 평가에 비유하여 설명합니다.
#
# ### 모델의 기본 개념
#
# 머튼 모델은 기업의 자산 가치를 높이 "기업 가치"라고 생각하고, 이를 유한한 만기를 가진 파생상품으로 간주합니다. 여기서 기업이 발행한 부채는 주식과 같은 파생상품으로 해석될 수 있습니다. 즉, 기업이 채무를 이행하지 못했을 때, 부채는 자산 가치가 계약된 일정 수준 이하로 떨어졌음을 의미합니다.
#
# ### 구성 요소
#
# 1. **자산 가치 (V)**: 기업의 총 자산 가치를 나타냅니다.
# 2. **부채 (D)**: 기업이 지닌 부채의 총액입니다.
# 3. **주식 (Equity)**: 기업의 소유자에게 귀속되는 자산의 잔여 청구권입니다.
# 4. **자산 변동성 (σ)**: 기업 자산의 수익률 변동성을 나타내며, 이는 주가의 변동성과 관련이 있습니다.
# 5. **위험 프리미엄**: 자산의 기대 수익률에서 무위험 수익률을 뺀 값입니다.
#
# ### 모델의 핵심 관계
#
# 머튼 모델은 다음과 같은 관계를 통해 기업의 부도율을 추정합니다:
#
# - **부도율(Probability of Default)**: 자산 가치가 부채 금액(D) 이하로 떨어질 확률로 정의됩니다. 즉, 자산 가치가 부채 가치보다 낮아질 때 기업이 파산하는 것입니다.
#
# - **Black-Scholes 방식**: 머튼 모델은 자산을 주식으로 보고, 회사의 부채를 차입금으로 간주하여 옵션 가격 모델인 블랙-숄즈(Black-Scholes) 모델을 활용하여 부도율을 추정합니다.
#
# ### 결론
#
# ...
