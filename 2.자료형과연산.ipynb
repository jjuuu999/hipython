# %% [markdown]
# - 기본 자료형 : 정수형, 실수형 > 숫자형, 문자형, 부울 형 boolean
# - 복합 자료형 : list, tuple, dictionary, set

# %% [markdown]
# # 기본자료형

# %% [markdown]
# ## int 정수형

# %%
20, type(20)
# Out:
# (20, int)

# %%
a = 20 #10진수
a
# Out:
# 20

# %%
a = 0b0101 # 2**2*1+2**0*1
a
# Out:
# 5

# %%
a = 0o10 #0b1000, 0x16d
a
# Out:
# 8

# %% [markdown]
# ## float

# %%
b=3.14
type (b), b
# Out:
# (float, 3.14)

# %% [markdown]
# ## 지수의 표기
# 10e2

# %%
a = 10e2
a
# Out:
# 1000.0

# %%
a = 10e-2 #10*10**-2
a
# Out:
# 0.1

# %%
3.1415e9
# Out:
# 3141500000.0

# %% [markdown]
# ## boolean 부울형
#
# True == 1 == 참, False == 0 == 거짓  예약어

# %%
a = 10
a = 3.14
a = 3.14e5
a = True; b = False
a, b
# Out:
# (True, False)

# %%
type (a), type (b)
# Out:
# (bool, bool)

# %%
a == 0 #== 같다 연산표시
# Out:
# False

# %%
a == 1
# Out:
# True

# %%
a == 2
# Out:
# False

# %%
a == true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 a == true
#
# NameError: name 'true' is not defined

# %%
a == "true"
# Out:
# False

# %%
b = 1
a and b, a, b
# Out:
# (1, True, 1)

# %%
c = 0
a and c
# Out:
# 0

# %% [markdown]
# ```
# and : a,b 모두 참(1)일 때 1, 아니면 0
# or : 둘 중 1개만 참(1)일 때 1
# not : 반대 참(1)이면 거짓(0),
# '''

# %%
a = True
b = 1
a + b
# Out:
# 2

# %%
a and b
# Out:
# 1

# %%
a and c
# Out:
# 0

# %%
if ( a and b ) : #조건식의 결과가 True(참)
    print ( 'hello' )
# Out:
# hello

# %%
if ( a and c ) : 
    print ( 'hi' )

# %%
print ( a >= 2, a>=1 )
# Out:
# False True

# %%
a = None
a

# %%
a or b
# Out:
# 1

# %%
a=2
b=3

# %%
a+b
# Out:
# 2

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 6

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 2

# %% [markdown]
# #비교연산 == != > < >= <=
# a == b
# a != b
# a > b
# a >= b

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a >= b
# Out:
# False

# %%
type (a-b)
# Out:
# int

# %% [markdown]
# #대입연산 = += -+

# %%
a = 10

# %%
a += 10
a
# Out:
# 120

# %%
b= 10
b += 5
b
# Out:
# 15

# %%
b -= 3
b
# Out:
# 12

# %% [markdown]
# # 문자열 str

# %%
first_name = 'hwiju'
last_name = 'go'
first_name+last_name
# Out:
# 'hwijugo'

# %%
last_name == 'Go' #대문자, 소문자 차이
# Out:
# False

# %%
last_name.lower ()
# Out:
# 'go'

# %%
last_name == 'Go'.lower ()
# Out:
# True

# %%
first_name.capitalize()
# Out:
# 'Hwiju'

# %%
first_name.upper()
# Out:
# 'HWIJU'

# %%
가사 = '''
Pinkfong
(상어 가족)
아기 상어 뚜루루 뚜루
귀여운 뚜루루 뚜루
바닷속 뚜루루 뚜루
아기 상어!
엄마 상어 뚜루루 뚜루
어여쁜 뚜루루 뚜루
바닷속 뚜루루 뚜루
엄마 상어!
아빠 상어 뚜루루 뚜루
힘이 센 뚜루루 뚜루
바닷속 뚜루루 뚜루
아빠 상어!
할머니 상어 (뚜루루 뚜루)
자상한 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할머니 상어!
할아버지 상어 (뚜루루 뚜루)
멋있는 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할아버지 상어!
우리는 뚜루루 뚜루
바다의 뚜루루 뚜루
사냥꾼 뚜루루 뚜루
상어 가족!
상어다 뚜루루 뚜루
도망쳐 뚜루루 뚜루
도망쳐 뚜루루 뚜루
숨자! 으악!
살았다 뚜루루 뚜루
살았다 뚜루루 뚜루
오늘도 뚜루루 뚜루
살았다 휴!
신난다 (뚜루루 뚜루)
신난다 (뚜루루 뚜루)
춤을 춰 뚜루루 뚜루
노래 끝! 오예!
'''

count = 가사.count("뚜루루 뚜루")
print ( count )
# Out:
# 27

# %%
count = 가사.count("뚜루루 뚜루")
print ( count )
# Out:
# 27

# %%
가사[0:10]
# Out:
# '\nPinkfong\n'

# %% [markdown]
# 주민등록번호의 생년월일 부분만 출력해보세요.

# %%
주민 = '001122-3123456'
print ( 주민[:6])
# Out:
# 001122

# %%
주민.split('-')[0]
# Out:
# '001122'

# %%
주민.split('00')[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 주민.split('00')[3]
#
# IndexError: list index out of range

# %%
if 주민 == '00' :
    print(주민[2:4], '월')
else :
    print(주민[4:6], '일')
# Out:
# 22 일

# %%
년 = 주민[0:2]
월 = 주민[2:4]
일 = 주민[4:6]

if 년 == '00':
    print(월+'월')
else :
    print(일+'일')
# Out:
# 11월

# %%
if 년 == '00':
    print (일+'일')
if 월 == '11':
    print('축하해')
# Out:
# 22일
# 축하해

# %%
주민번호 = '001122-3456789ab'

# %%
주민번호.split("-")[1][0],'1')
주민번호
# Out:
#   Cell In[161], line 1
#     주민번호.replace.split("-")[1][0],'1')
#                                      ^
# SyntaxError: unmatched ')'

# %%
주민번호.split("-")[1][0]
# Out:
# '3'

# %%
새_주민번호 = 주민번호.replace('3', '1')
새_주민번호
# Out:
# '001122-1456789ab'

# %%
count = 가사.count("뚜루루 뚜루")
print ( count )
# Out:
# 27

# %% [markdown]
# ## 인덱싱과 슬라이싱

# %%
text = "python"
print ( text[-1] )
print ( text[::2] )
print ( text[::3] )
# Out:
# n
# pto
# ph

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(text)
# Out:
# No Python documentation found for 'python'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
'a'.encode( 'utf-8' )
dec_value = 'a'.encode( 'utf-16' )
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16')
# Out:
# 'a'

# %%
# format()
#test_str = ' 99.99 dollars are wroth us $ 100 입니다.'
test_str = ' {0:.4f} {1:s} are wroth us {2:s} {3:d} 입니다.'
test_str.format(99.99,'dollars','$',100)
# Out:
# ' 99.9900 dollars are wroth us $ 100 입니다.'

# %%
num1 = 99.99
num2 = 100
str1 = 'dollars'
str2 = '$'
test_str = f' {num1:.4f} {str1:s} are worth us {str2:s} {num2:d} 입니다. '
test_str
# Out:
# ' 99.9900 dollars are worth us $ 100 입니다. '

# %%
len ( test_str )
# Out:
# 41

# %%
email = 'aaa@gmail.com'
email_1 = 'aaa@gmail.com '

len (email) , len (email_1)
# Out:
# (13, 14)

# %%
len( email_1.strip() )
# Out:
# 13

# %%
len ( email.strip() ), len ( email_1.strip() )
# Out:
# (13, 13)

# %%
가사
# Out:
# '\nPinkfong\n(상어 가족)\n아기 상어 뚜루루 뚜루\n귀여운 뚜루루 뚜루\n바닷속 뚜루루 뚜루\n아기 상어!\n엄마 상어 뚜루루 뚜루\n어여쁜 뚜루루 뚜루\n바닷속 뚜루루 뚜루\n엄마 상어!\n아빠 상어 뚜루루 뚜루\n힘이 센 뚜루루 뚜루\n바닷속 뚜루루 뚜루\n아빠 상어!\n할머니 상어 (뚜루루 뚜루)\n자상한 (뚜루루 뚜루)\n바닷속 뚜루루 뚜루\n할머니 상어!\n할아버지 상어 (뚜루루 뚜루)\n멋있는 (뚜루루 뚜루)\n바닷속 뚜루루 뚜루\n할아버지 상어!\n우리는 뚜루루 뚜루\n바다의 뚜루루 뚜루\n사냥꾼 뚜루루 뚜루\n상어 가족!\n상어다 뚜루루 뚜루\n도망쳐 뚜루루 뚜루\n도망쳐 뚜루루 뚜루\n숨자! 으악!\n살았다 뚜루루 뚜루\n살았다 뚜루루 뚜루\n오늘도 뚜루루 뚜루\n살았다 휴!\n신난다 (뚜루루 뚜루)\n신난다 (뚜루루 뚜루)\n춤을 춰 뚜루루 뚜루\n노래 끝! 오예!\n'

# %%
가사.rfind("뚜루루") #index 반환
# Out:
# 395

# %%
가사[395:398]
# Out:
# '뚜루루'

# %%
dir(email)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(.lstrip)
# Out:
#   Cell In[34], line 1
#     help(.lstrip)
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 문자열
#
# 1. 인덱싱, 슬라이싱, 멤버십
# 2. 문자열은 immutable "불변", 대소문자 구분한다
# 3. 문자열은 코드를 지정 인코딩, 디코딩, 유니코드(이모지), 한글
# 4. 문자열 + , *
# 5. 공백처리, 형식처리 등을 해야 한다.

# %%
import re

text = "파이썬   문자열   처리"
clean = re.sub(r"\s+", " ", text)

print (clean)
# Out:
# 파이썬 문자열 처리

# %%
re.sub(r"\s+", " " , text)
# Out:
# '파이썬 문자열 처리'

# %%
tel_no = '010-1234-5678'
re.sub(r'-' , "" , tel_no)
# Out:
# '01012345678'

# %%
re.sub(r'\D' , "" , tel_no)
# Out:
# '01012345678'

# %%
#생성자 creator, function > 단독적으로 사용 가능. 
int(1)
float(1)
str(1)

#복합자료형
list('1') #[ ]
tuple('1') #( )
dict() # { }
set('1') # { }
# Out:
# {'1'}

# %%
# 사칙연산자, 비교 연산자, 대입연산자, 논리연산자, 기타...
+, -, *, /, %, //
<, >, ==, !=
 =, +=, -+, *=, /=
and, or, not, &, |, !
in

# %%
dir([1,2])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list_object.insert()
list_object.append()
