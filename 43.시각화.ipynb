# %% [markdown]
# # 시각화 라이브러리 설치

# %% [markdown]
# # 설정 : 경고 & 한글폰트 적용

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
# 적용 잘 됐는지 확인용
import matplotlib.pyplot as plt
plt.title('클래스와 오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

# %%
d1.describe(), d2.describe()
# Out:
# (               x          y
#  count  11.000000  11.000000
#  mean    9.000000   7.500909
#  std     3.316625   2.031568
#  min     4.000000   4.260000
#  25%     6.500000   6.315000
#  50%     9.000000   7.580000
#  75%    11.500000   8.570000
#  max    14.000000  10.840000,
#                 x          y
#  count  11.000000  11.000000
#  mean    9.000000   7.500909
#  std     3.316625   2.031657
#  min     4.000000   3.100000
#  25%     6.500000   6.695000
#  50%     9.000000   8.140000
#  75%    11.500000   8.950000
#  max    14.000000   9.260000)

# %%
plt.plot(d1['x'],d1['y'], 'o') # 'o'를 넣어서 산점도를 보여줌.

# %%
plt.plot(d2['x'],d2['y'], 'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1) #2row, 2col,position
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot( d1['x'], d1['y'] , 'o')
axes2.plot( d2['x'], d2['y'] , 'o')
axes3.plot( d3['x'], d3['y'] , 'o')
axes4.plot( d4['x'], d4['y'] , 'o')

axes1.set_title('dataset I')
axes2.set_title('dataset II')
axes3.set_title('dataset III')
axes4.set_title('dataset IV')

fig.suptitle('Anscombe Dataset 으로 보는 데이터 시각화의 의미')
fig.set_tight_layout(True)
plt.show()

# %% [markdown]
# # 차트의 구성

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %%
plt.figure(figsize=(10,8)) # 차트의 크기
plt.title('Stock Prices Over 5 Days')
plt.xlabel('Date')
plt.ylabel('Price')
plt.plot(dates, prices, marker='o') # x,y축 - dates,prices
plt.legend()
plt.grid()
plt.ylim(95,110)
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
plt.subplot(1,2,1)
plt.plot(dates, prices, marker='o', color='green')
plt.xticks(rotation =45)
plt.title("Stock Prices - Subplot 1")

plt.subplot(1,2,2)
plt.bar(dates, prices, color='orange')
plt.savefig('my_chart.png')
plt.title("Stock Prices - Subplot 2")
plt.xticks(rotation =45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '2024-10-01'),
#   Text(1, 0, '2024-10-02'),
#   Text(2, 0, '2024-10-03'),
#   Text(3, 0, '2024-10-04'),
#   Text(4, 0, '2024-10-05')])

# %% [markdown]
# # 용도에 맞는 차트 그리기

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 1변량 그래프 : 히스토그램 - 구간, 빈도수

# %%
plt.hist(data=tips_df, x='total_bill', bins=10, rwidth=0.8)
plt.title('총 금액')
# Out:
# Text(0.5, 1.0, '총 금액')

# %%
#total_bill vs. tip
plt.subplot(1,2,1)
plt.hist(data=tips_df, x='total_bill', bins=10, rwidth=0.8, color='orange')

plt.subplot(1,2,2,)
plt.hist(data=tips_df, x='tip', bins=10, rwidth=0.8, color='green')
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 1변량 그래프 : 박스플롯

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(tips_df.nunique())
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
for i in tips_df:
  print(f'{i}: {tips_df[i].unique()}')
# Out:
# total_bill: [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
tips_df['sex']=='Female'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
plt.boxplot([tips_df[tips_df['sex']=='Female']['total_bill'],
            tips_df[tips_df['sex']=='Female']['tip']],
            labels=['total_bill/Female', 'tip/Female']
            )
plt.title('Female_total_bill&tip')
plt.show()

# %%
plt.boxplot([tips_df[tips_df['sex']=='Male']['total_bill'],
            tips_df[tips_df['sex']=='Male']['tip']],
            labels=['total_bill/Male', 'tip/Male']
            )
plt.title('Male_total_bill&tip')
plt.show()

# %%
tips_df[tips_df['sex']=='Male']['total_bill']
# Out:
# 1      10.34
# 2      21.01
# 3      23.68
# 5      25.29
# 6       8.77
#        ...
# 236    12.60
# 237    32.83
# 239    29.03
# 241    22.67
# 242    17.82
# Name: total_bill, Length: 157, dtype: float64

# %%
tips_df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
plt.figure(figsize=(15, 12))

plt.subplot(2,2,1)
plt.boxplot([tips_df[tips_df['day']=='Sun']['total_bill'],
            tips_df[tips_df['day']=='Sun']['tip']],
            labels=['total_bill/Sun', 'tip/Sun']
            )
plt.ylim(0, 60)

plt.subplot(2,2,2)
plt.boxplot([tips_df[tips_df['day']=='Sat']['total_bill'],
            tips_df[tips_df['day']=='Sat']['tip']],
            labels=['total_bill/Sat', 'tip/Sat']
            )
plt.ylim(0, 60)

plt.subplot(2,2,3)
plt.boxplot([tips_df[tips_df['day']=='Thur']['total_bill'],
            tips_df[tips_df['day']=='Thur']['tip']],
            labels=['total_bill/Thur', 'tip/Thur']
            )
plt.ylim(0, 60)

plt.subplot(2,2,4)
plt.boxplot([tips_df[tips_df['day']=='Fri']['total_bill'],
            tips_df[tips_df['day']=='Fri']['tip']],
            labels=['total_bill/Fri', 'tip/Fri']
            )
plt.ylim(0, 60)

plt.show()

# %%
tips_df.groupby(['day','time']).size()
# Out:
# day   time
# Thur  Lunch     61
#       Dinner     1
# Fri   Lunch      7
#       Dinner    12
# Sat   Lunch      0
#       Dinner    87
# Sun   Lunch      0
#       Dinner    76
# dtype: int64

# %%
plt.figure(figsize=(15, 12))

plt.subplot(2,2,1)
plt.boxplot([tips_df[(tips_df['day']=='Sun')&(tips_df['time']=='Lunch')]['total_bill'],
            tips_df[(tips_df['day']=='Sun')&(tips_df['time']=='Lunch')]['tip']],
            labels=['total_bill/Sun_Lunch', 'tip/Sun_Lunch']
            )
plt.ylim(0, 60)

plt.subplot(2,2,2)
plt.boxplot([tips_df[(tips_df['day']=='Sun')&(tips_df['time']=='Dinner')]['total_bill'],
            tips_df[(tips_df['day']=='Sun')&(tips_df['time']=='Dinner')]['tip']],
            labels=['total_bill/Sun_Dinner', 'tip/Sun_Dinner']
            )
plt.ylim(0, 60)

plt.subplot(2,2,3)
plt.boxplot([tips_df[(tips_df['day']=='Sat')&(tips_df['time']=='Lunch')]['total_bill'],
            tips_df[(tips_df['day']=='Sat')&(tips_df['time']=='Lunch')]['tip']],
            labels=['total_bill/Sat_Lunch', 'tip/Sat_Lunch']
            )
plt.ylim(0, 60)

plt.subplot(2,2,4)
plt.boxplot([tips_df[(tips_df['day']=='Sat')&(tips_df['time']=='Dinner')]['total_bill'],
            tips_df[(tips_df['day']=='Sat')&(tips_df['time']=='Dinner')]['tip']],
            labels=['total_bill/Sat_Dinner', 'tip/Sat_Dinner']
            )
plt.ylim(0, 60)

plt.show()
# 너무 번거롭... 씨본 써서 hue로 time 나누기..

# %%
plt.figure(figsize=(12, 6))

# x축은 요일, y축은 금액, 색깔(hue)은 점심/저녁으로 구분!
sns.boxplot(data=tips_df, x='day', y='total_bill', hue='time', palette='coolwarm',
            order=['Thur', 'Fri', 'Sat', 'Sun'])

plt.title('Total Bill by Day and Time')
plt.show()

# %%
# 1. 전체 도화지 크기를 가로로 길게 설정 (가로 16, 세로 6)
plt.figure(figsize=(16, 6))

# 2. 첫 번째 칸: Total Bill 분석
plt.subplot(1, 2, 1)
sns.boxplot(data=tips_df, x='day', y='total_bill', hue='time', palette='coolwarm',
            order=['Thur', 'Fri', 'Sat', 'Sun'])
plt.title('Total Bill by Day and Time')

# 3. 두 번째 칸: Tip 분석
plt.subplot(1, 2, 2)
sns.boxplot(data=tips_df, x='day', y='tip', hue='time', palette='Pastel1',
            order=['Thur', 'Fri', 'Sat', 'Sun'])
plt.title('Tip by Day and Time')

# 그래프 간격 조절 및 출력
plt.tight_layout()
plt.show()

# %%
plt.boxplot(data=tips_df,x='total_bill')
plt.grid()
plt.show()

# %%
plt.boxplot([tips_df['total_bill'], tips_df['tip']])
plt.grid()
plt.show()

# %%
plt.subplot(1,2,1)
plt.boxplot(data=tips_df,x='total_bill')
plt.title('총금액')

plt.subplot(1,2,2)
plt.boxplot(data=tips_df,x='tip')
plt.title('팁')
# Out:
# Text(0.5, 1.0, '팁')

# %% [markdown]
# # seaborn 시각화

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_tips = sns.load_dataset('tips')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=df_tips, x='total_bill',\
  y='tip', \
  col='time', \
  hue='smoker', \
  style='time', size='size')

# %%
sns.scatterplot(data=df_tips, x='total_bill', y='tip', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
